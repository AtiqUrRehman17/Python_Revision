# %% [markdown]
# ### Full OOP Practice

# %%
class Atm:
    # constructor
    def __init__(self):
        self.pin = ''
        self.balance = 0

        self.menu()
        print(id(self))

    def menu(self):
        user_input = input('''
                How would you like to proceed
                1.enter 1 to create pin
                2.enter 2 to deposite
                3.enter 3 to withdraw
                4.enter 4 to check balance
                5.enter 5 to exit
                ''')

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposite()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('bye')

    # now we have to write methods for each functionality

    def create_pin(self):
        user_pin = int(input('enter your pin'))
        self.pin = user_pin
        print('pin created successfully')
        self.menu()

    def deposite(self):
        temp = int(input('enter your pin please'))
        if temp == self.pin:
            amount = int(input('enter amount please'))
            self.balance = self.balance + amount
            print('deposite successfull')
        else:
            print('invalid pin')
        self.menu()

    def withdraw(self):
        temp = int(input('enter your pin please'))
        if temp == self.pin:
            amount = int(input('enter amount please'))
            if amount < self.balance:
                self.balance = self.balance - amount
            else:
                print('insufficent Funds')
        else:
            print('invalid pin')
        self.menu()

    def check_balance(self):
        temp = int(input('enter your pin please'))
        if temp == self.pin:
            print(self.balance)
        else:
            print('invalid pin')

# %%
ubl = Atm()
# Out:
# pin created successfully
# bye
# 1287670993248

# %%
print(id(ubl))
# Out:
# 1287670993248

# %%
abl = Atm()
# Out:
# bye
# 1287672350032

# %%
print(id(abl))
# Out:
# 1287672350032

# %%
ubl.deposite()
# Out:
# deposite successfull
# bye

# %%
ubl.check_balance()
# Out:
# 200

# %%
ubl.withdraw()
# Out:
# bye

# %%
ubl.check_balance()
# Out:
# 100

# %% [markdown]
# -------------------

# %% [markdown]
# ### Encapsulation

# %%
class Atm:
    # constructor
    def __init__(self):
        self.pin = ''
        self.balance = 0

        self.menu()
        # print(id(self))

    def menu(self):
        user_input = input('''
                How would you like to proceed
                1.enter 1 to create pin
                2.enter 2 to deposite
                3.enter 3 to withdraw
                4.enter 4 to check balance
                5.enter 5 to exit
                ''')

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposite()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('bye')

    # now we have to write methods for each functionality

    def create_pin(self):
        user_pin = int(input('enter your pin'))
        self.pin = user_pin
        print('pin created successfully')
        self.menu()

    def deposite(self):
        temp = int(input('enter your pin please'))
        if temp == self.pin:
            amount = int(input('enter amount please'))
            self.balance = self.balance + amount
            print('deposite successfull')
        else:
            print('invalid pin')
        self.menu()

    def withdraw(self):
        temp = int(input('enter your pin please'))
        if temp == self.pin:
            amount = int(input('enter amount please'))
            if amount < self.balance:
                self.balance = self.balance - amount
            else:
                print('insufficent Funds')
        else:
            print('invalid pin')
        self.menu()

    def check_balance(self):
        temp = int(input('enter your pin please'))
        if temp == self.pin:
            print(self.balance)
        else:
            print('invalid pin')

# %%
hbl = Atm()
# Out:
# pin created successfully
# bye

# %%
hbl.pin
# Out:
# 121

# %%
hbl.balance
# Out:
# 0

# %%
hbl.balance = 'jhbscdskcj'

# %%
hbl.balance
# Out:
# 'jhbscdskcj'

# %%
hbl.deposite()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 hbl.deposite()
#
# Cell In[30], line 43, in Atm.deposite(self)
#      39     def deposite(self):
#      40         temp = int(input('enter your pin please'))
#      41         if temp == self.pin:
#      42             amount = int(input('enter amount please'))
# ---> 43             self.balance = self.balance + amount
#      44             print('deposite successfull')
#      45         else:
#      46             print('invalid pin')
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Through an error beacuse first we store string and then we add integer.so the coes crashes
# -------------------------
# Now we have to apply encapsulation to hide the data from the user so he can't access it and also can't change it.

# %%
class Atm:
    # constructor
    def __init__(self):
        self.__pin = ''
        self.__balance = 0

        self.menu()
        # print(id(self))

    def menu(self):
        user_input = input('''
                How would you like to proceed
                1.enter 1 to create pin
                2.enter 2 to deposite
                3.enter 3 to withdraw
                4.enter 4 to check balance
                5.enter 5 to exit
                ''')

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposite()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('bye')

    # now we have to write methods for each functionality

    def create_pin(self):
        user_pin = int(input('enter your pin'))
        self.__pin = user_pin
        print('pin created successfully')
        self.menu()

    def deposite(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            self.__balance = self.__balance + amount
            print('deposite successfull')
        else:
            print('invalid pin')
        self.menu()

    def withdraw(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            if amount < self.__balance:
                self.__balance = self.__balance - amount
            else:
                print('insufficent Funds')
        else:
            print('invalid pin')
        self.menu()

    def check_balance(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            print(self.balance)
        else:
            print('invalid pin')

# %%
allied = Atm()
# Out:
# pin created successfully
# bye

# %%
# allied. 
# now the alled object cannot access the data

# %% [markdown]
# ### Also if we want we can hide methods as well using encapsulation.
# ------------------------------
# Lets hide the deposite Methode for an object of the class

# %%
class Atm:
    # constructor
    def __init__(self):
        self.__pin = ''
        self.__balance = 0

        self.menu()
        # print(id(self))

    def menu(self):
        user_input = input('''
                How would you like to proceed
                1.enter 1 to create pin
                2.enter 2 to deposite
                3.enter 3 to withdraw
                4.enter 4 to check balance
                5.enter 5 to exit
                ''')

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.__deposite()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('bye')

    # now we have to write methods for each functionality

    def create_pin(self):
        user_pin = int(input('enter your pin'))
        self.__pin = user_pin
        print('pin created successfully')
        self.menu()

    def __deposite(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            self.__balance = self.__balance + amount
            print('deposite successfull')
        else:
            print('invalid pin')
        self.menu()

    def withdraw(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            if amount < self.__balance:
                self.__balance = self.__balance - amount
            else:
                print('insufficent Funds')
        else:
            print('invalid pin')
        self.menu()

    def check_balance(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            print(self.balance)
        else:
            print('invalid pin')

# %%
allied = Atm()
# Out:
# pin created successfully
# bye

# %%
# allied. 
# also the deposite method is hided from the allied object of the class

# %% [markdown]
# ### Here we can give the option to the user to see and also if he wants he can change the pin and balance using two more methods called set_pin and get_pin

# %%
class Atm:
    # constructor
    def __init__(self):
        self.__pin = ''
        self.__balance = 0

        
        self.menu()
        # print(id(self))
    def get_pin(self):
            return self.__pin
        
    def set_pin(self,new):
        if type(new) == int:
            self.__pin = new
        else:
            print('Not allowed')

    def menu(self):
        user_input = input('''
                How would you like to proceed
                1.enter 1 to create pin
                2.enter 2 to deposite
                3.enter 3 to withdraw
                4.enter 4 to check balance
                5.enter 5 to exit
                ''')

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposite()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('bye')

    # now we have to write methods for each functionality

    def create_pin(self):
        user_pin = int(input('enter your pin'))
        self.__pin = user_pin
        print('pin created successfully')
        self.menu()

    def deposite(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            self.__balance = self.__balance + amount
            print('deposite successfull')
        else:
            print('invalid pin')
        self.menu()

    def withdraw(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            if amount < self.__balance:
                self.__balance = self.__balance - amount
            else:
                print('insufficent Funds')
        else:
            print('invalid pin')
        self.menu()

    def check_balance(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            print(self.balance)
        else:
            print('invalid pin')

# %%
mcb = Atm()
# Out:
# pin created successfully
# bye

# %%
mcb.get_pin()
# Out:
# 111

# %%
mcb.set_pin(222)

# %%
mcb.get_pin()
# Out:
# 222

# %% [markdown]
# ## Static Methods
# --------------------------------

# %%
class Atm:

    counter = 1
    # constructor
    def __init__(self):
        self.__pin = ''
        self.__balance = 0

        self.sno = Atm.counter
        Atm.counter = Atm.counter +1

        
        self.menu()
        # print(id(self))
    def get_pin(self):
            return self.__pin
        
    def set_pin(self,new):
        if type(new) == int:
            self.__pin = new
        else:
            print('Not allowed')

    def menu(self):
        user_input = input('''
                How would you like to proceed
                1.enter 1 to create pin
                2.enter 2 to deposite
                3.enter 3 to withdraw
                4.enter 4 to check balance
                5.enter 5 to exit
                ''')

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposite()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('bye')

    # now we have to write methods for each functionality

    def create_pin(self):
        user_pin = int(input('enter your pin'))
        self.__pin = user_pin
        print('pin created successfully')
        self.menu()

    def deposite(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            self.__balance = self.__balance + amount
            print('deposite successfull')
        else:
            print('invalid pin')
        self.menu()

    def withdraw(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            if amount < self.__balance:
                self.__balance = self.__balance - amount
            else:
                print('insufficent Funds')
        else:
            print('invalid pin')
        self.menu()

    def check_balance(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            print(self.balance)
        else:
            print('invalid pin')

# %%
ubl = Atm()
# Out:
# pin created successfully
# bye

# %%
hbl = Atm()
# Out:
# pin created successfully
# bye

# %%
ubl.sno
# Out:
# 1

# %%
hbl.sno
# Out:
# 2

# %%
class Atm:

    counter = 1
    # constructor
    def __init__(self):
        self.__pin = ''
        self.__balance = 0

        self.sno = Atm.counter
        Atm.counter = Atm.counter +1

        
        self.menu()
        # print(id(self))
    def get_pin(self):
            return self.__pin
        
    def set_pin(self,new):
        if type(new) == int:
            self.__pin = new
        else:
            print('Not allowed')

    # static methods
    @staticmethod
    def get_sno():
        return Atm.counter

    @staticmethod
    def set_sno(new):
        if type(new) == int:
            Atm.counter = new
        else:
            print('Not allowed')

    def menu(self):
        user_input = input('''
                How would you like to proceed
                1.enter 1 to create pin
                2.enter 2 to deposite
                3.enter 3 to withdraw
                4.enter 4 to check balance
                5.enter 5 to exit
                ''')

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposite()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print('bye')

    # now we have to write methods for each functionality

    def create_pin(self):
        user_pin = int(input('enter your pin'))
        self.__pin = user_pin
        print('pin created successfully')
        self.menu()

    def deposite(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            self.__balance = self.__balance + amount
            print('deposite successfull')
        else:
            print('invalid pin')
        self.menu()

    def withdraw(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            amount = int(input('enter amount please'))
            if amount < self.__balance:
                self.__balance = self.__balance - amount
            else:
                print('insufficent Funds')
        else:
            print('invalid pin')
        self.menu()

    def check_balance(self):
        temp = int(input('enter your pin please'))
        if temp == self.__pin:
            print(self.balance)
        else:
            print('invalid pin')

# %%
ubl = Atm()
# Out:
# pin created successfully
# bye

# %%
hbl = Atm()
# Out:
# pin created successfully
# bye

# %%
# its throgh an error becuse for accessing static variable we dont need an object we can call it using the class name.
ubl.get_sno()

# %%
ubl.get_sno()
# Out:
# 3

# %%
ubl.set_sno(100)

# %%
ubl.get_sno()
# Out:
# 100

# %% [markdown]
# ### Aggregation VS Inheritance
# ---------------------

# %%
class Coustomer:
    # cnstructor
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    
class Address:
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode = pincode
        self.state = state

# %%
add = Address('lahore',1001,'kpk')

# %%
coust = Coustomer('atiq','male',add)

# %%
print(coust.address.city)
# Out:
# lahore

# %%
class Coustomer:
    # cnstructor
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    
    # one method for changing profile

    def edit_profile(self,new_gender,new_address):
        self.name = self.name
        self.gender = new_gender
        self.address = new_address

    
class Address:
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode = pincode
        self.state = state

    # one method for changb city

    def change_address(self,new_city,new_pincode,new_state):
        self.city = new_city
        self.pincode = new_pincode
        self.state = new_state

# %%
add = Address('lahore',1001,'kpk')

# %%
coust = Coustomer('atiq','male',add)

# %%
print(coust.address.city)
# Out:
# lahore

# %%
coust.address.change_address('islamabad',1002,'islamabad')
print(coust.address.city)
# Out:
# islamabad

# %% [markdown]
# ### Inheritance
# ---------------------

# %%
class Users:
    def login(self):
        print('Login successfull')

    def register(self):
        print('Ragistration Successfull')


class Student(Users):


    def enroll(self):
        print('Enrolled')

    def review(self):
        print('Reviewed')

class Teacher(Users):

    def create(self):
        print('Created')

    def q_a(self):
        print('Q&A')

# %%
st = Student()

# %%
st.login()
# Out:
# Login successfull

# %%
st.register()
# Out:
# Ragistration Successfull

# %%
st.enroll()
# Out:
# Enrolled

# %%
te = Teacher()

# %%
te.login()
# Out:
# Login successfull

# %%
te.register()
# Out:
# Ragistration Successfull

# %%
te.create()
# Out:
# Created

# %% [markdown]
# ### Lets inherit the Construcor of the parent Class

# %%
class Phone:
    print('Inside the Constructor')
    def __init__(self,price,brand,camera):
        self.price = price
        self.brand = brand
        self.camera = camera


class Smartphone(Phone):
    pass
# Out:
# Inside the Constructor

# %%
smart = Smartphone(10000, "Apple", 48)

# %%
print(smart.price)
# Out:
# 10000

# %%
print(smart.brand)
# Out:
# Apple

# %% [markdown]
# ## Super function
# ---------------------

# %%
class Phone:
    print('Inside the Constructor')
    def __init__(self,price,brand,camera):
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print('bought inside the phone class')

class Smartphone(Phone):
    
    def buy(self):
        print('bought inside the smartphone class')

        super().buy()
# Out:
# Inside the Constructor

# %%
b = Smartphone(10000, "Apple", 48)

# %%
b.buy()
# Out:
# bought inside the smartphone class
# bought inside the phone class
