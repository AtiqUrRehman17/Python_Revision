# %% [markdown]
# ### String Part 1
# String is a sequence of charctor

# %% [markdown]
# ### 1. Creating strings
# in python there are many ways to create a string as follow

# %%
c= 'khan'
c
# Out:
# 'khan'

# %%
c = "khan"
c
# Out:
# 'khan'

# %%
'its'raning today"
# here the pytho will confuse that where the string is start and where its end 
# so u can use the dubble qutation to print the string
# Out:
#   Cell In[6], line 1
#     'its'raning today"
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"its'raning today"
# Out:
# "its'raning today"

# %%
c = '''Hello'''
c
# here this is used when u want to write mulyi lines strings
# Out:
# 'Hello'

# %%
# u can also create a string by type convertion like
c = str('hello')
c
# Out:
# 'hello'

# %% [markdown]
# --------
# # String Part 2 :
# ## Accsessing substring from a String

# %%
# Here We will Understand two concepts Indexing and slicing
# 1. INDEXING
c = 'Hello'
c
# Out:
# 'Hello'

# %%
# here the output is the sequence of charator where each chaartor have index number
c[1]
# Out:
# 'e'

# %% [markdown]
# ### Indexing Have Two Types
# 1. Postive Indexing the Above indexing
# 2. Nagative Indexing

# %%
c[-4] # From right to left
# Out:
# 'e'

# %% [markdown]
# ### Slicing :
# Here throgh indexing u can take only one charator\
# but throgh slicing u can get myltiple chartors and that is called Slicing

# %%
c = 'Hello World'
c
# Out:
# 'Hello World'

# %%
# here if i wnat to print only Hello and i will provide a range like
c[0:5]
# u will count the the word that u wnat to print
# Out:
# 'Hello'

# %%
# here u can also  give anything like 
c[2:]
# it means print all after the second index of the string
# Out:
# 'llo World'

# %%
# u can also give like 
c[:2]
# it means to print from start to the second index of the string
# Out:
# 'He'

# %%
# here u can also give nothing which means print evry thig in the string
c[:]
# Out:
# 'Hello World'

# %%
# here one more thing is used whaich is for skippin the charctor like
c[0:8:2]
# here it means that print the charator from 0 to 8 and skip after every two charctor
# Out:
# 'HloW'

# %%
# here is one more concept is used like
c[::-1]
# so by this syntax the string will be reversed
# Out:
# 'dlroW olleH'

# %% [markdown]
# ------
# # Edit And Delete String :

# %%
c = 'hello'
c
# Out:
# 'hello'

# %%
# here if i wnat to change the first charator of the string removing h and adding x then
c[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # here if i wnat to change the first charator of the string removing h and adding x then
# ----> 2 c[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
# here it gives me an error that u cant edit a string in python

# %%
# here u can completely reassin new thing but u can not change the existing one
c = 'World'
c
# Out:
# 'World'

# %% [markdown]
# #### Note : Note that We cannot edit a string and also we cannot

# %%
# here  now lets see the deletion in string
# for deletion of string in python there is built in function of del and the string will be deleted
c = 'world'
c
# Out:
# 'world'

# %%
del c

# %%
c
# here the c is deletd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
# here it comes a question
c = 'hello'
print(c)
# Out:
# hello

# %%
# here lets check that we want to delete the first char in the string
del c[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # here lets check that we want to delete the first char in the string
# ----> 2 del c[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
# so same that we cannot delete and char from the string

# %% [markdown]
# -------------------
# ### Operation On string
# 1. Arithematic Operation
# 2. Relational Operation
# 3. Logical Operation
# 4. Loop on strings
# 5. Membership Opertaion

# %% [markdown]
# ### Arethimatic Operaion
# Here in string U can Perfprm only two arithematic operation which is + and *

# %%
# here the + Is used For string concatination like
'Hello' + 'World'
# Out:
# 'HelloWorld'

# %%
'Hello' + "-" + 'World'
# Out:
# 'Hello-World'

# %%
# the second one is Multiplecation
print('hello' * 5)
# whicj means to multiply the string 5 times
# Out:
# hellohellohellohellohello

# %% [markdown]
# ### Relational Operators
# here throgh string u can use all the realtional operators

# %%
'hello' == 'world'
# false becase both are not same
# Out:
# False

# %%
'hello' != 'world'
# True becase both are not same
# Out:
# True

# %%
# the intersting thing is when u do the following
'mumbai' > 'pune'
# here it giving me false becase of lexigraphically lexigraphically means the word which comes last in the alphbets
# that will be geater now here p comes second as compare to m
# Out:
# False

# %%
'Goa' < 'Kolkata'
# here same
# Out:
# True

# %% [markdown]
# ### Logical Operator

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
# now here we will be thinking that why world comes first Now Always remember that python undertand the
# empty string as fasle and non empty string as true so when u use the and or operators like
'' and 'hello'
# here for and operator both condition if true the it comes true otherwise its false now first string is empty
# which means false and true = fasle in the and operator
# Out:
# ''

# %%
'' or 'khan'
# same logic
# Out:
# 'khan'

# %% [markdown]
# ### Loops On String

# %%
# here lets an example
c = 'Hello World'
for i in c:
    print(i)
# here the i will take one charc and print it till last
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
# here u can also use the slicing in the loop
c = 'Hello World'
for i in c[2:]:
    print(i)
# and etc
# Out:
# l
# l
# o
#
# W
# o
# r
# l
# d

# %% [markdown]
# ### Memebership Operator
# Which is In and Not In

# %%
c = 'Hello World'
'H' in c
# it is True  means h is avliable in the string
# Out:
# True

# %%
'C' in c
# same C in not avlbale in the sting
# Out:
# False

# %%
'K' not in c
# Out:
# True
