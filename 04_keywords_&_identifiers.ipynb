# %% [markdown]
# ## **Keywords and Identifiers**
# Python is a case sensetive proggraming Language

# %% [markdown]
# In Proggramming , keyword is a word that is reserved by a program becase the word has special meaning,
# kewords can be cammands or parameters.Every language is set of keywords that can not be used as variable name.

# %%
# In python there are 33 different Keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## **Identifiers** :
# A python identifer is a name used to indentify a varilable , class , function ,or a madule and or other object

# %% [markdown]
# ### Rules For Setting an Identifier :
# 1. can only start with an alphbet or _
# 2. Followed by 0 or more latter _ and digits
# 3. keywords cannot used as an identifiers

# %%
name = 'Atiq'
name
# Out:
# 'Atiq'

# %%
_ = 'Khan'
print(_)
# Out:
# Khan

# %%
# but u cannot give digit
1 = 'Atiq'
print(1)
# Out:
#   Cell In[4], line 2
#     1 = 'Atiq'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# same cannot give special charactors
@ = 2
print(@)
# Out:
#   Cell In[5], line 2
#     @ = 2
#       ^
# SyntaxError: invalid syntax

# %%
# same in the begging u cannot use the digits but after first name u can use only one speicl charctor '_'
first_name = 'Atiq'
print(first_name)
# Out:
# Atiq

# %%
# And last u cannot give a keyword as an identifier like the above keyword u cannot assing
False = 'Atiq'
print(False)
# Out:
#   Cell In[7], line 2
#     False = 'Atiq'
#     ^
# SyntaxError: cannot assign to False
